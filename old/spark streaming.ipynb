# %%
# %load_ext autoreload
# %autoreload 2

from deltahelper import get_delta, get_spark, get_delta_spark
from load_db import handle_ticker, main, add_ticker_day_todb
delta_table = get_delta()
from imports import dt, START_DATE
# main(load_diff_only=False)
# Out:
# 22/12/22 20:33:41 WARN Utils: Your hostname, macOS-bowles-2.local resolves to a loopback address: 127.0.0.1; using 192.168.1.9 instead (on interface en0)
# 22/12/22 20:33:41 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/Users/bowles/spark-3.3.1-bin-hadoop3/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/bowles/.ivy2/cache
# The jars for the packages stored in: /Users/bowles/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-f880f196-f3ab-4986-9915-829b0f94883e;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.1.1 in central
# 	found io.delta#delta-storage;2.1.1 in central
# 	found org.antlr#antlr4-runtime;4.8 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in local-m2-cache
# :: resolution report :: resolve 93ms :: artifacts dl 3ms
# 	:: modules in use:
# ...

# %%
existingdeltadf = get_delta_spark()
ticker_name='AAPL'
tickerdf = existingdeltadf.filter(f"ticker == '{ticker_name}'").select('*').toPandas()
# Out:
# 22/12/22 20:48:47 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
dict(tickerdf.groupby('Date').count()["Datetime"])
# Out:
# {'2012-05-16': 677,
#  '2012-05-17': 696,
#  '2012-05-18': 707,
#  '2012-05-21': 697,
#  '2012-05-22': 670,
#  '2012-05-23': 715,
#  '2012-05-24': 652,
#  '2012-05-25': 598,
#  '2012-05-29': 622,
#  '2012-05-30': 669,
#  '2012-05-31': 667,
#  '2012-06-01': 667,
#  '2012-06-04': 657,
#  '2012-06-05': 580,
#  '2012-06-06': 651,
#  '2012-06-07': 623,
#  '2012-06-08': 648,
#  '2012-06-11': 711,
#  '2012-06-12': 622,
#  '2012-06-13': 568,
#  '2012-06-14': 584,
#  '2012-06-15': 607,
#  '2012-06-18': 618,
#  '2012-06-19': 623,
#  '2012-06-20': 546,
#  '2012-06-21': 554,
#  '2012-06-22': 573,
#  '2012-06-25': 564,
#  '2012-06-26': 552,
#  '2012-06-27': 540,
#  '2012-06-28': 560,
#  '2012-06-29': 647,
#  '2012-07-02': 607,
#  '2012-07-03': 363,
#  '2012-07-05': 629,
#  '2012-07-06': 613,
#  '2012-07-09': 618,
#  '2012-07-10': 656,
#  '2012-07-11': 642,
#  '2012-07-12': 610,
#  '2012-07-13': 583,
#  '2012-07-16': 526,
#  '2012-07-17': 577,
#  '2012-07-18': 629,
#  '2012-07-19': 660,
# ...

# %%
int(hashlib.sha1('ssfdss'.encode("utf-8")).hexdigest(), 16) % (10 ** 8)
# Out:
# 25342521

# %%
import hashlib
